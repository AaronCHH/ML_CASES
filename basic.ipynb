# %%
import os, sys, glob
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import scipy as sp
import csv
import geopandas as gpd
import shapely.wkt
import matplotlib as mpl
import seaborn as sns
from shapely.geometry import Point, LineString

# %%
nb_sample = 100
X_data = np.random.normal(loc=0.0, scale=np.sqrt(2.0), size=nb_sample)

# %%
plt.plot(X_data)

# %%
def negative_log_likelihood(v):
  l = 0.0
  f1 = 1.0 / np.sqrt(2.0 * np.pi * v[1])
  f2 = 2.0 * v[1]

  for x in X_data:
    l += np.log(f1 * np.exp(-np.sqrt(x-v[0]) /f2 ))
    
  return -l

# %%
from scipy.optimize import minimize

# %%
minimize(fun=negative_log_likelihood, x0=[0.0, 1.0])
# Out:
# C:\ANACONDA\Anaconda\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys
#       fun: nan
#  hess_inv: array([[1, 0],
#        [0, 1]])
#       jac: array([nan, nan])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 4
#       nit: 0
#      njev: 1
#    status: 2
#   success: False
#         x: array([0., 1.])
